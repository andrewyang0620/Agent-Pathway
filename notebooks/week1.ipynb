# %% [markdown]
# ## Week 1 - Environment & Foundations

# %% [markdown]
# ### 1. Start ups
#
# under the root:
#
# ```terminal
# python -m venv .venv
# ```
#
# activate the virtual environment:
#
# ```terminal
# .venv\Scripts\activate
# ```

# %% [markdown]
# ### 2. Useful tools
#
# #### 2.1 Pydantic
#
# ```terminal
# pip install pydantic
# ```
#
# Sample Usage:

# %%
from pydantic import BaseModel
from typing import Optional

class DiscountDecision(BaseModel):
    approved: bool
    max_discount_pct: float
    reason: str
    policy_reference: Optional[str] = None

# %% [markdown]
# #### 2.2 Rich
#
# ```terminal
# pip install rich
# ```
#
# Sample Usage:

# %%
from rich import print
from rich.panel import Panel
from rich.markdown import Markdown

print({"approved": True, "max_discount": 0.08})

# panel装饰
md = Markdown("## 结论\n建议折扣不超过 **8%**")
print(Panel(md, title="AI 回答", border_style="yellow"))
# Out:
# {'approved': True, 'max_discount': 0.08}
# ╭──────────────────────────────────────────────────── AI 回答 ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │                                                      结论                                                       │
# │                                                                                                                 │
# │ 建议折扣不超过 8%                                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# #### 2.3 Loguru
#
# ```terminal
# pip install loguru
# ```
# Sample Usage:

# %%
from loguru import logger

logger.info("开始查询客户 A 的折扣上限")
logger.warning("当前毛利率接近下限，建议谨慎")
logger.error("无法连接数据库")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from loguru import logger
#       3 logger.info("开始查询客户 A 的折扣上限")
#       4 logger.warning("当前毛利率接近下限，建议谨慎")
#
# ModuleNotFoundError: No module named 'loguru'
